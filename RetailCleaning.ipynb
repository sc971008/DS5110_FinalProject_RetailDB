# %%
import pandas as pd

# %%
#Imports Retail data to be cleaned
Retail = pd.read_csv('/content/Retail.csv')

# %%
#Checks for correct data
Retail.head()
# Out:
#    InvoiceNo InvoiceDate  StockCode  Quantity
# 0     536598  2017-01-01      21421         1
# 1     536598  2017-01-01      21422         2
# 2     536598  2017-01-01      22178        26
# 3     536599  2017-01-01      20749         2
# 4     536599  2017-01-01      21056         2

# %%
#This code groups the data by the primary keys, then merges duplicate data so that
#transactions for the same product code within the same invoice are together
new_Retail = Retail.groupby(['InvoiceNo','InvoiceDate','StockCode']).sum()
#Resets index so group_by becomes dataframe
new_Retail = new_Retail.reset_index()

# %%
#Checks an example whether data was cleaned
new_Retail[(new_Retail['InvoiceNo'] == 580137) & (new_Retail["InvoiceDate"] == '2017-12-31') & (new_Retail['StockCode'] == 21034)]
# Out:
#         InvoiceNo InvoiceDate  StockCode  Quantity
# 176770     580137  2017-12-31      21034         5

# %%
#Writes cleaned data to new csv
new_Retail.to_csv('/content/Clean_Retail.csv', columns = ['InvoiceNo', 'InvoiceDate', 'StockCode', 'Quantity'], index_label = False)

# %%
clean_Retail = pd.read_csv('/content/Clean_Retail.csv')

# %%
#Check clean data
clean_Retail
# Out:
#         InvoiceNo InvoiceDate  StockCode  Quantity
# 0          536598  2017-01-01      21421         1
# 1          536598  2017-01-01      21422         2
# 2          536598  2017-01-01      22178        26
# 3          536599  2017-01-01      20749         2
# 4          536599  2017-01-01      21056         2
# ...           ...         ...        ...       ...
# 176779     580137  2017-12-31      22113         1
# 176780     580137  2017-12-31      22138         1
# 176781     580137  2017-12-31      22178         1
# 176782     580137  2017-12-31      22197         3
# 176783     580137  2017-12-31      22217         1
#
# [176784 rows x 4 columns]
